# %% [markdown]
# # Lab #4 - Data Cleaning
# by: DEL

# %% [markdown]
# ## Introduction
# This lab is a little different than labs we have done before. In this lab, we will be cleaning different datasets. I will be cleaing different columns to make the datasets easier to read.

# %% [markdown]
# ## Dataset Exploration

# %%
# always include aliased modules
# these are the most common ones that we'll use in our Big Data class
import math as m
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
attendance_df = pd.read_excel("attendance.xlsx") 

sales_df = pd.read_csv("sales.csv" , encoding = "iso-8859-1")

candy_df= pd.read_excel("BOING-BOING-CANDY-HIERARCHY-2016-SURVEY-Responses.xlsx", encoding = "iso-8859-1" )

# %% [markdown]
# I am now going to look at the head of the attendance dataset. I have to remember it is an excel not a csv!

# %%
# read in our small but messy test file
df_simple = pd.read_excel("attendance.xlsx")
df_simple.head(7)
# Out:
#   Table 43. Average daily attendance (ADA) as a percentage of total enrollment, school day length, and school year length in public schools, by school level and state: 2007-08  \
# 0                                                NaN
# 1                                                NaN
# 2                                                  1
# 3                             United States ........
# 4                          Alabama .................
# 5                          Alaska ..................
# 6                          Arizona .................
#
#                                           Unnamed: 1  Unnamed: 2  \
# 0  Total elementary, secondary, and combined elem...         NaN
# 1                       ADA as percent of enrollment         NaN
# 2                                                  2         NaN
# 3                                             93.079    0.218555
# 4                                            93.8124    1.237261
# ...

# %% [markdown]
# Now I am going to open the Boing Boing Candy data. Again, I have to remember that this is an excel file and not a csv! I will take the header to see what I am working with.

# %%
# read in our small but messy test file
df_simple = pd.read_excel("BOING-BOING-CANDY-HIERARCHY-2016-SURVEY-Responses.xlsx")
df_simple.head(7)
# Out:
#                 Timestamp  \
# 0 2016-10-24 05:09:23.033
# 1 2016-10-24 05:09:54.798
# 2 2016-10-24 05:13:06.734
# 3 2016-10-24 05:14:17.192
# 4 2016-10-24 05:14:24.625
# 5 2016-10-24 05:16:43.126
# 6 2016-10-24 05:16:50.572
#
#   Are you going actually going trick or treating yourself? Your gender:  \
# 0                                                 No               Male
# 1                                                 No               Male
# 2                                                 No             Female
# 3                                                 No               Male
# 4                                                Yes               Male
# 5                                                 No               Male
# 6                                                Yes               Male
#
#   How old are you? Which country do you live in?  \
# 0               22                        Canada
# 1               45                           usa
# ...

# %% [markdown]
# Finally, I am going to open the sales data. This is a csv file so I had to put csv. For some reason, it did not work at first but now it is working because I had to add the encoding.

# %%
# read in our small but messy test file
df_simple = pd.read_csv("sales.csv",  encoding = "iso-8859-1")

df_simple.head(7)
# Out:
#    Unnamed: 0              event_id        primary_act_id  \
# 0           1  abcaf1adb99a935fc661  43f0436b905bfa7c2eec
# 1           2  6c56d7f08c95f2aa453c  1a3e9aecd0617706a794
# 2           3  c7ab4524a121f9d687d2  4b677c3f5bec71eec8d1
# 3           4  394cb493f893be9b9ed1  b1ccea01ad6ef8522796
# 4           5  55b5f67e618557929f48  91c03a34b562436efa3c
# 5           6  4f10fd8b9f550352bd56  ac4b847b3fde66f2117e
# 6           7  105ea9ee10065b54b0df  a14232befff04be1e2f3
#
#        secondary_act_id   purch_party_lkup_id  \
# 0  b85143bf51323b72e53c  7dfa56dd7d5956b17587
# 1  f53529c5679ea6ca5a48  4f9e6fc637eaf7b736c2
# 2  b85143bf51323b72e53c  6c2545703bd527a7144d
# 3  b85143bf51323b72e53c  527d6b1eaffc69ddd882
# 4  b85143bf51323b72e53c  8bd62c394a35213bdf52
# 5  63814f3d63317f1b56c4  3b3a628f83135acd0676
# 6  b85143bf51323b72e53c  14af02b72584fa823f85
#
#                                           event_name  \
# 0  Xfinity Center Mansfield Premier Parking: Flor...
# ...

# %% [markdown]
# I am now going to do info on each dataset.

# %% [markdown]
# ## Dataset Preparation 1

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 46 columns):
# Unnamed: 0                5000 non-null int64
# event_id                  5000 non-null object
# primary_act_id            5000 non-null object
# secondary_act_id          5000 non-null object
# purch_party_lkup_id       5000 non-null object
# event_name                5000 non-null object
# primary_act_name          5000 non-null object
# secondary_act_name        1586 non-null object
# major_cat_name            5000 non-null object
# minor_cat_name            5000 non-null object
# la_event_type_cat         5000 non-null object
# event_disp_name           5000 non-null object
# ticket_text               5000 non-null object
# tickets_purchased_qty     5000 non-null int64
# trans_face_val_amt        5000 non-null float64
# delivery_type_cd          5000 non-null object
# event_date_time           5000 non-null object
# event_dt                  5000 non-null object
# ...

# %%
attendance_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68 entries, 0 to 67
# Data columns (total 17 columns):
# Table 43. Average daily attendance (ADA) as a percentage of total enrollment, school day length, and school year length in public schools, by school level and state: 2007-08    57 non-null object
# Unnamed: 1                                                                                                                                                                       55 non-null object
# Unnamed: 2                                                                                                                                                                       52 non-null float64
# Unnamed: 3                                                                                                                                                                       54 non-null object
# ...

# %%
candy_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1259 entries, 0 to 1258
# Columns: 123 entries, Timestamp to  [York Peppermint Patties] Ignore
# dtypes: datetime64[ns](1), float64(1), object(121)
# memory usage: 1.2+ MB

# %% [markdown]
# ## Dataset Preparation 2

# %% [markdown]
# This is a test, I am not using attendance data. I am using the sales data and the candy data but I wanted to test one of the cleaning functions on this dataset before the next ones.

# %%
# read in our small but messy test file
df_simple = pd.read_csv("sales.csv",  encoding = "iso-8859-1")

df_simple.head(7)
# Out:
#    Unnamed: 0              event_id        primary_act_id  \
# 0           1  abcaf1adb99a935fc661  43f0436b905bfa7c2eec
# 1           2  6c56d7f08c95f2aa453c  1a3e9aecd0617706a794
# 2           3  c7ab4524a121f9d687d2  4b677c3f5bec71eec8d1
# 3           4  394cb493f893be9b9ed1  b1ccea01ad6ef8522796
# 4           5  55b5f67e618557929f48  91c03a34b562436efa3c
# 5           6  4f10fd8b9f550352bd56  ac4b847b3fde66f2117e
# 6           7  105ea9ee10065b54b0df  a14232befff04be1e2f3
#
#        secondary_act_id   purch_party_lkup_id  \
# 0  b85143bf51323b72e53c  7dfa56dd7d5956b17587
# 1  f53529c5679ea6ca5a48  4f9e6fc637eaf7b736c2
# 2  b85143bf51323b72e53c  6c2545703bd527a7144d
# 3  b85143bf51323b72e53c  527d6b1eaffc69ddd882
# 4  b85143bf51323b72e53c  8bd62c394a35213bdf52
# 5  63814f3d63317f1b56c4  3b3a628f83135acd0676
# 6  b85143bf51323b72e53c  14af02b72584fa823f85
#
#                                           event_name  \
# 0  Xfinity Center Mansfield Premier Parking: Flor...
# ...

# %% [markdown]
# I am going to look at sales data and rename all of the columns.

# %%
# I am going to rename colmuns with the function {“old_column_name”: “new_column_name”}
sales_df.rename(columns ={
                          sales_df.columns[1]: "event",
                          sales_df.columns[2]: "primary act", 
                          sales_df.columns[3]: "secondary act",
                          sales_df.columns[4]: "punch part",
                          sales_df.columns[5]: "name of primary act",
                          sales_df.columns[6]: "name of secondary act",
                          sales_df.columns[7]: "major cat name",
                          sales_df.columns[8]: "minor cat name"}, 

                            inplace = True)  
sales_df.head()
# Out:
#    Unnamed: 0                 event           primary act  \
# 0           1  abcaf1adb99a935fc661  43f0436b905bfa7c2eec
# 1           2  6c56d7f08c95f2aa453c  1a3e9aecd0617706a794
# 2           3  c7ab4524a121f9d687d2  4b677c3f5bec71eec8d1
# 3           4  394cb493f893be9b9ed1  b1ccea01ad6ef8522796
# 4           5  55b5f67e618557929f48  91c03a34b562436efa3c
#
#           secondary act            punch part  \
# 0  b85143bf51323b72e53c  7dfa56dd7d5956b17587
# 1  f53529c5679ea6ca5a48  4f9e6fc637eaf7b736c2
# 2  b85143bf51323b72e53c  6c2545703bd527a7144d
# 3  b85143bf51323b72e53c  527d6b1eaffc69ddd882
# 4  b85143bf51323b72e53c  8bd62c394a35213bdf52
#
#                                  name of primary act  \
# 0  Xfinity Center Mansfield Premier Parking: Flor...
# 1      Gorge Camping - dave matthews band - sept 3-7
# 2        Dodge Theatre Adams Street Parking - benise
# 3  Gexa Energy Pavilion Vip Parking : kid rock wi...
# 4                      Premier Parking - motley crue
#
# ...

# %% [markdown]
# Renmaming the columns would make it easier to read the dataset and it would be more ogranized.

# %% [markdown]
# With the sales data, I am not going to group by event to see if I can take out repeats or unnecessary data.

# %%
sales_df.groupby("event").count()
# Out:
#                       Unnamed: 0  primary act  secondary act  punch part  \
# event
# 00071bfcbb27802045b2           1            1              1           1
# 001889c0940fa4fae413           1            1              1           1
# 00394b832432576b931a           1            1              1           1
# 00454c7a335c30d982d7           1            1              1           1
# 004ac78a434a108b6421           1            1              1           1
# 0058bfb31860d317d0b0           1            1              1           1
# 006a0a56ab8c9d2e22fe           1            1              1           1
# 006e23bc4f830f9ca009           2            2              2           2
# 00a27f2ddd44b968708b           1            1              1           1
# 00a8e302cde4b003a053           2            2              2           2
# 00be0fdc7cc9999fdf59           1            1              1           1
# 00be3916736a92dbc24a           1            1              1           1
# ...

# %% [markdown]
# Now, I am going to look at the Boing Boing Candy Sata and I am going to delete the York Peppermint Patties because  it tells me to ignore it on the dataset.

# %%
df_simple = pd.read_excel("BOING-BOING-CANDY-HIERARCHY-2016-SURVEY-Responses.xlsx")
df_simple.head(7)
"[York Peppermint Patties]Ignore"

# %% [markdown]
# I am now going to rename the columns because the columns are very messy and long. I want them to be short and to the point. I am going to open and read the head portion of the Boing Boing Candy dataset to see what I am working with.

# %%
# read in our small but messy test file
df_simple = pd.read_excel("BOING-BOING-CANDY-HIERARCHY-2016-SURVEY-Responses.xlsx") 

df_simple.head(7)
# Out:
#                 Timestamp  \
# 0 2016-10-24 05:09:23.033
# 1 2016-10-24 05:09:54.798
# 2 2016-10-24 05:13:06.734
# 3 2016-10-24 05:14:17.192
# 4 2016-10-24 05:14:24.625
# 5 2016-10-24 05:16:43.126
# 6 2016-10-24 05:16:50.572
#
#   Are you going actually going trick or treating yourself? Your gender:  \
# 0                                                 No               Male
# 1                                                 No               Male
# 2                                                 No             Female
# 3                                                 No               Male
# 4                                                Yes               Male
# 5                                                 No               Male
# 6                                                Yes               Male
#
#   How old are you? Which country do you live in?  \
# 0               22                        Canada
# 1               45                           usa
# ...

# %% [markdown]
# I am now going to rename the columns in the Boing Boing Candy dataset. This will allow me to read the columns better and make it easier to read.

# %%
# I am going to rename colmuns with the function {“old_column_name”: “new_column_name”}
candy_df.rename(columns ={
                          candy_df.columns[1]: "Time",
                          candy_df.columns[2]: "Gender", 
                          candy_df.columns[3]: "Age",
                          candy_df.columns[4]: "Location",
                          candy_df.columns[5]: "100 Grand",
                          candy_df.columns[6]: "Black and Orange Globs",
                          candy_df.columns[7]: "Full Sized Candy Bar",
                          candy_df.columns[8]: "Black Jacks", 
                          candy_df.columns[9]: "Degree of Seperation: J.K Rowling", 
                          candy_df.columns[10]: "Degree of Seperation: JJ Adams", 
                          candy_df.columns[11]: "Degree of Seperation: Beyonce",
                          candy_df.columns[12]: "Degree of Seperation: Justin Beiber",
                          candy_df.columns[13]: "Degree of Speration: Kevin Beacom", 
                          candy_df.columns[14]: "Day Pref",
                          candy_df.columns[15]: "How do you eat Apples?",
                          candy_df.columns[16]: "What websites do you look at?"},
    
                            inplace=True)  
candy_df.head()
# Out:
#                 Timestamp Time  Gender Age Location     100 Grand  \
# 0 2016-10-24 05:09:23.033   No    Male  22   Canada       Ontario
# 1 2016-10-24 05:09:54.798   No    Male  45      usa            il
# 2 2016-10-24 05:13:06.734   No  Female  48       US      Colorado
# 3 2016-10-24 05:14:17.192   No    Male  57      usa            il
# 4 2016-10-24 05:14:24.625  Yes    Male  42      USA  South Dakota
#
#   Black and Orange Globs Full Sized Candy Bar Black Jacks  \
# 0                    JOY              DESPAIR         JOY
# 1                    MEH                  MEH         JOY
# 2                    JOY              DESPAIR         JOY
# 3                    JOY                  MEH         JOY
# 4                    MEH              DESPAIR         JOY
#
#   Degree of Seperation: J.K Rowling  ...  \
# 0                               MEH  ...
# 1                               JOY  ...
# 2                               MEH  ...
# 3                               MEH  ...
# ...

# %% [markdown]
# I am now going to use the groupby() function to group by gender. I am going to group by gender to see if men, women or people who don't want to share distribute amongst the data.

# %%
candy_df.groupby("Gender").count()
# Out:
#                     Timestamp  Time  Age  Location  100 Grand  \
# Gender
# Female                    410   410  401       403        381
# I'd rather not say         28    28   24        26         23
# Male                      795   795  779       787        756
# Other                      17    17   17        17         15
#
#                     Black and Orange Globs  Full Sized Candy Bar  Black Jacks  \
# Gender
# Female                                 381                   405          406
# I'd rather not say                      26                    26           27
# Male                                   751                   777          785
# Other                                   16                    17           16
#
#                     Degree of Seperation: J.K Rowling  \
# Gender
# Female                                            334
# I'd rather not say                                 23
# Male                                              678
# ...

# %% [markdown]
# ## Conclusion

# %% [markdown]
# This was Lab was very hard, it was really hard. The Boing-Boing-Candy data was very messy. I was very confused that there were no actually candy but more long titles. The sales data also had super long headers that was super hard to figure out. I think overall with more time and I could finish it and understand it more. If I had more time, I think I could have cleaned more.

# %% [markdown]
# ## Awknowledgments

# %% [markdown]
# Shoutout to Theo for always being open to help me with my code errors! I also wanna thank Navya for coming in and looking at my code, same for Ziah for helping me with my code and then shoutout to Ms. Sconyers for helping me with my rename and telling me why it wasn't working.
